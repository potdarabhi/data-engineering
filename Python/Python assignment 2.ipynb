# %%
import csv

with open('customers.csv',mode = 'r') as file:
  reader = csv.reader(file)
  for row in reader:
    print(row)

# %%
import csv

try:
    with open('customer1.csv',mode = 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)

except FileNotFoundError:
    print("File not found")

except Exception as e:
    print(f'Exception {e} was occured')

# %%
import csv

with open('customers.csv',mode = 'a') as file:
    writer = csv.writer(file)
    writer.writerow(['C004','John','Pune','2500'])
    print('Successfully appended')
