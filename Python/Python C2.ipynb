# %% [markdown]
# ###File Handling

# %% [markdown]
# ### Reading CSV

# %%
import csv

with open('global_food_wastage_dataset.csv',mode = 'r') as wastagefile:
  reader = csv.reader(wastagefile)
  next(reader) #used when you want to skip the header
  for row in reader:
    print(row)

# %%
with open('global_food_wastage_dataset.csv',mode = 'r') as wastagefile:
  reader = csv.DictReader(wastagefile)
  for row in reader:
    print(row['Country'])

# %% [markdown]
# ### Writing to CSV

# %%
import csv

with open('output.csv', mode='w') as file:
    writer = csv.writer(file)
    writer.writerow(['id', 'name'])
    writer.writerow([1, 'John'])
    writer.writerow([2, 'Jane'])

# %% [markdown]
# ###Fetch data from API

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/40381/hscard"

headers = {
	"x-rapidapi-key": "e9c9174e1dmsh0ffd3be55aed72dp1980edjsnc9605cafe757",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())

# %% [markdown]
# ###MINI PROJECT: File + API + Logic
#   ✅ Task:
#
# - Fetch users from API
# - Filter users from a specific city
# - Write to a CSV

# %%
import requests,csv

response = requests.get('https://jsonplaceholder.typicode.com/users')

if response.status_code == 200:
    users = response.json()
    
    with open('users.csv', mode='w') as file:
        writer = csv.writer(file)
        writer.writerow(['Name','City'])

        for user in users:
            if user['address']['city'] == 'South Christy':
                writer.writerow([user['name'], user['address']['city']])
else:
    print("Failed to fetch data")
